# %%
# %pylab notebook
r = linspace(0.001,10,100)
n = 1
k = 20
u1 = k * r**n
u2 = 1/(2*r**2)
u = u1+u2
plt.plot(r,u1, '-.', r,u2, "b--", r,u)
plt.legend(["U1", "U2", "U"]);
plt.axis((0,10,-20,20))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <img src="data:image/png;base64,..." width="432">
# (0, 10, -20, 20)
# <img src="data:image/png;base64,..." width="432">

# %%
# %pylab inline
r = linspace(0.001,1,100)
n = -1
k = 20
u1 = -k * r**n
u2 = 1/(2*r**2)
u = u1+u2
plt.plot(r,u1, ':', r,u2, "b--", r,u)
plt.legend(["U1", "U2", "U"]);
plt.axis((0,1,-200,100))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (0, 1, -200, 100)

# %%
# %pylab inline
r = linspace(0.001,3,100)
n = -3
k = 2
u1 = -k * r**n
u2 = 1/(2*r**2)
u = u1+u2
plt.plot(r,u1, ':', r,u2, "b--", r,u)
plt.legend(["U1", "U2", "U"]);
plt.axis((0,3,-10,10))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (0, 3, -10, 10)

# %%
# %pylab inline
r = linspace(0.001,3,10000)
u1 = -2/3 * r**(-3/2)
u2 = 1/2 * r**(-2)
u = u1+u2
plt.plot(r,u1, r, u2, r,u)
plt.axis((0,3,-0.2,0.2))
plt.legend(["U1","U2","U"])
# Out:
# Populating the interactive namespace from numpy and matplotlib
